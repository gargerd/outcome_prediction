# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(style='whitegrid',font_scale=2)
import os
import pickle
import time

os.getcwd()
os.chdir(os.getcwd())
os.getcwd()
# Out:
# '/Users/daniel.garger/Desktop/Projects/C-PATH/outcome prediction/src'

# %% [markdown]
# ### Read the dtaframes containing patient IDs and available variables

# %%
#variables_per_patient_all=pd.read_csv('../../C-Path_data/preprocessing/all_pat_variables.csv',index_col=0,low_memory=False)
outcome_df=pd.read_csv('../../C-Path_data/preprocessing/tb_1018_20_21_22_30_outcome.csv',index_col=0)
dm=pd.read_csv('../../C-path_data/fullExportDb-1025-Member-CSV/dm.csv',low_memory=False)

# %%
pat_id_df=outcome_df[['USUBJID','STUDYID']]
pat_id_df['USUBJID'] = pat_id_df['USUBJID'].str.replace('\\', '/', regex=False)

## Add ARM information from dm dataframe
dm=dm.set_index('USUBJID')
pat_id_df=pat_id_df.set_index('USUBJID')
pat_id_df['ARM']=dm.loc[pat_id_df.index.tolist(),'ARM']
pat_id_df=pat_id_df.reset_index()
pat_id_df.to_csv('../data/patients_in_analysis.csv.gz',compression='gzip')
# Out:
# /var/folders/0_/_m74rlq93855zphvhkg3qkhh19_hwl/T/ipykernel_88738/633073929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pat_id_df['USUBJID'] = pat_id_df['USUBJID'].str.replace('\\', '/', regex=False)
